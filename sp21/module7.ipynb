# %% [markdown]
# ## Module 7: Building A Linear Regression Model
#
# - Video: Extending Single Variable Regression to Multiple Regression, least squares, preprocessing(more math/stats heavy)(Ervin)
#  1. choosing 2 variables, do OLS
#  2. choosing 3 variables, same OLS but predicting on 2 variables
#  3. need mathetatical formula for both (first one can come from data8 testbook)
# - Video: Introduction to sklearn (varun)
#     do the same 2 OLS as above, but with sklearn
# - Video: Interpreting your sklearnregression(coefficient significance) (varun)
#     how to read the slope and intercets from the output, maybe add in some diagnostic stats from other functions in sklearn
# - Optional reading - dummy encoding (Grace)
#     find another dataset to do dummy encoding on, maybe do a MV OLS.
# - Optional - data transformations (log transformations, polynomial kernels) (Grace)
#     a lot of plots.

# %% [markdown]
# ## Single Variable Regression
#
# In Data 8 you learned the formula:
#
# $$\textrm{predicted value} = \textrm{slope} * x + \textrm{intercept}$$
#
# Where $x$ is the value that you are trying to extract
# a prediction for. Rather than writing out $\textrm{predicted value}$, $\textrm{slope}$, and $\textrm{intercept}$ we'll start using a more formal and rigorous
# version of the forumla. Don't worry about the scary math symbols! They mean the exact same thing.
#
# Thus, using scary math symbols, the formula looks like the following:
#
# $$\hat{y} = \beta x + \alpha$$
#
# Where $\hat{y}$ is our predicted value, $$

# %% [markdown]
# ## New markdown cell
